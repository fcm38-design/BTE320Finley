# %% [markdown]
# <a href="https://colab.research.google.com/github/fcm38-design/BTE320Finley/blob/main/In_Class_Assignments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sales = float(input("Enter sales ($): "))

cogs = 0.40 * sales
gross_profit = sales - cogs

print(f"Sales: {sales}$")
print(f"Cost of Goods Sold: {cogs}$")
print(f"Gross Profit: {gross_profit}$")
# Out:
# Enter sales ($): 12000
# Sales: 12000.0$
# Cost of Goods Sold: 4800.0$
# Gross Profit: 7200.0$

# %%
sales = float(input("Enter sales ($): "))
tax_rate = float(input("Enter tax rate (%): ")) /100

cogs = 0.40 * sales
gross_profit = sales - cogs
taxes = gross_profit * tax_rate
net_income = gross_profit - taxes

print(f"Sales: {sales}$")
print(f"Cost of Goods Sold: {cogs}$")
print(f"Gross Profit: {gross_profit}$")
print(f"Taxes: {taxes}$")
print(f"Net Income: {net_income}$")
# Out:
# Enter sales ($): 12000
# Enter tax rate (%): 30
# Sales: 12000.0$
# Cost of Goods Sold: 4800.0$
# Gross Profit: 7200.0$
# Taxes: 2160.0$
# Net Income: 5040.0$

# %%
Number1 = input("Enter number for value 1:")
Number2 = input("Enter number for value 2:")

Operator = input("Enter operator (+, -, *, /, **, %):")

if Operator == "+":
  print (int(Number1) + int(Number2))
elif Operator == "-":
  print (int(Number1) - int(Number2))
elif Operator == "*":
  print (int(Number1) * int(Number2))
elif Operator == "/":
    print (int(Number1) / int(Number2))
elif Operator == "**":
  print (int(Number1) ** int(Number2))
elif Operator == "%":
  print (int(Number1) % int(Number2))
else:
    print("Invalid operator")
# Out:
# Enter number for value 1:5
# Enter number for value 2:6
# Enter operator (+, -, *, /, **, %):**
# 15625
