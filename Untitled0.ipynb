# %% [markdown]
# <a href="https://colab.research.google.com/github/fcm38-design/BTE320Finley/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
interest = 3
principal = 3000
n =1
final = principal * (1+intrest/100)**n
print(final)
# Out:
# 3090.0

# %%
print("Interest rate:", intrest, "; Number of years =", n)
# Out:
# Interest rate: 3 ; Number of years = 1

# %%
interest = float(input("Set interest value (%): "))
principal = float(input("enter initial amount on the account ($): "))
n = int(input("Enter number of years: "))

final = principal * (1+intrest/100)**n

print(f"Total amount after {n} year(s): {final}$")\
# Out:
# Set interest value (%): 3
# enter initial amount on the account ($): 3000
# Enter number of years: 1
# Total amount after 1 year(s): 3090.0$
